# %% [markdown]
# # Approximating Optimized Model Coefficients

# %%
import numpy as np
import pandas as pd
import math
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pylab as pl
from IPython.html.widgets import *

# %%
PendData = np.loadtxt('data/pendData.csv', skiprows=1, delimiter=',')
PendFrame = pd.DataFrame(PendData,columns=['time(sec)','angular position(theta)'])

# %%
plt.figure(figsize=(18,6))

plt.scatter(PendFrame['time(sec)'],PendFrame['angular position(theta)'], s=8, c='black')
pendTS = pd.Series(PendFrame['angular position(theta)'], index =PendFrame['time(sec)'])
pendTS[0:] = PendFrame['angular position(theta)']
#TSPlot = PendFrame.plot(x='time(sec)',y='angular position(theta)',ylim=(-22,20),
                        #linewidth=.7, c='green')
TSPlot = pendTS.plot(ylim=(-22,20),linewidth=.7, c='green')
TSPlot.set_axis_bgcolor('white')
TSPlot.set_ylabel('pendulum angular position (degrees)', fontsize=16)
TSPlot.set_xlabel('time (seconds)',fontsize=16)
TSPlot.set_title('Pendulum Position Time Series',fontsize=20)
plt.tick_params(axis='both', labelsize=15)

# %% [markdown]
# <img src="images/dampedSin.PNG">

# %%
def sine_wave(time,amp,freq,phi,vertShift,damp):
    return ((math.exp(-1*damp*time))*(amp*math.sin(2*math.pi*freq*time-phi)+vertShift))

# %% [markdown]
# Where: <br>
#    t = Time, in seconds<br>
#    A = Peak Amplitude<br>
#    f = Frequency, in Hz<br>
#    &Phi; = Phase Shift<br>
#    B = Vertical shift

# %%
def sine_values(amp,freq,phi,vertShift,damp):
    PendFrame['SineValues']= PendFrame.apply(lambda row: sine_wave(row['time(sec)'],amp,freq,phi,vertShift,damp),axis=1)

# %%
def sine_values2(amp,freq,phi,vertShift,damp):
    sineValues = []
    for time in PendFrame['time(sec)']:
        sineValues.append(sine_wave(time,amp,freq,phi,vertShift,damp))
    ts = pd.Series(sineValues, index = PendFrame['time(sec)'])
    return ts

# %%
def model(amp,freq,phi,vertShift,damp):
    
    ts =sine_values2(amp,freq,phi,vertShift,damp)

    plt.figure(figsize=(18,6))

    #TSPlot = PendFrame.plot(x='time(sec)',y='angular position(theta)',ylim=(-22,20),linewidth=.7, c='red')
    TSPlot = pendTS.plot(ylim=(-22,22),linewidth=.7, c='red')
    ts.plot(linewidth=.7, c='blue')
    
    #PendFrame.plot(x='time(sec)',y='SineValues',ylim=(-22,22),linewidth=.7, c='blue')
    #plt.axis([0.0,36.0,-22.0,22.0])
    TSPlot.set_axis_bgcolor('white')
    TSPlot.set_ylabel('pendulum angular position (degrees)', fontsize=16)
    TSPlot.set_xlabel('time (seconds)',fontsize=16)
    TSPlot.set_title('Approximating Model Coefficients',fontsize=20)
    TSPlot.legend(['Fit Data','Model','Observed Data Points (time,theta)'],1)
    plt.tick_params(axis='both', labelsize=15)
    
    SSE = np.sum((PendFrame['angular position(theta)']-PendFrame['SineValues'])**2)
    print("SSE:",SSE)

# %%
interact(model,amp=(15.0,25.0,.001),freq=(1.0,2.0,.001),phi=(-1.0,1,.001),vertShift=(-2.0,2.0,.001),damp=(.001,.1,.001));
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-683fe622ed93> in model(amp, freq, phi, vertShift, damp)
#      18     plt.tick_params(axis='both', labelsize=15)
#      19
# ---> 20     SSE = np.sum((PendFrame['angular position(theta)']-PendFrame['SineValues'])**2)
#      21     print("SSE:",SSE)
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1676             return self._getitem_multilevel(key)
#    1677         else:
# -> 1678             return self._getitem_column(key)
#    1679
#    1680     def _getitem_column(self, key):
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1683         # get column
#    1684         if self.columns.is_unique:
# -> 1685             return self._get_item_cache(key)
#    1686
#    1687         # duplicate columns & possible reduce dimensionaility
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    2563
#    2564             if not isnull(item):
# -> 2565                 loc = self.items.get_loc(item)
#    2566             else:
#    2567                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\core\index.pyc in get_loc(self, key)
#    1179         loc : int if unique index, possibly slice or mask if not
#    1180         """
# -> 1181         return self._engine.get_loc(_values_from_object(key))
#    1182
#    1183     def get_value(self, series, key):
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\index.pyd in pandas.index.IndexEngine.get_loc (pandas\index.c:3656)()
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\index.pyd in pandas.index.IndexEngine.get_loc (pandas\index.c:3534)()
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\hashtable.pyd in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:11911)()
#
# C:\Users\flunk_000\Anaconda2\lib\site-packages\pandas\hashtable.pyd in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:11864)()
#
# KeyError: 'SineValues'

# %%
amp = 19.649
freq = 1.26082
phi = .18205
vertShift = -.4705
damp = .02695
PendFrame['SineValues']= PendFrame.apply(lambda row: sine_wave(row['time(sec)'],amp,freq,phi,vertShift,damp),axis=1)
SSE = np.sum((PendFrame['angular position(theta)']-PendFrame['SineValues'])**2)
print("SSE:",SSE)

# %%
plt.figure(figsize=(18,6))
plt.scatter(PendFrame['time(sec)'],PendFrame['angular position(theta)'], s=8, c='black')
TSPlot = PendFrame.plot(x='time(sec)',y='angular position(theta)',ylim=(-22,20),linewidth=.7, c='red')
PendFrame.plot(x='time(sec)',y='SineValues',ylim=(-22,22),linewidth=.7, c='blue')
TSPlot.set_axis_bgcolor('white')
TSPlot.set_ylabel('pendulum angular position (degrees)', fontsize=16)
TSPlot.set_xlabel('time (seconds)',fontsize=16)
TSPlot.set_title('Pendulum Position Time Series: Model and Observed Fit',fontsize=20)
TSPlot.legend(['Fit Data','Model','Observed Data Points (time,theta)'],1)
plt.tick_params(axis='both', labelsize=15)

# %%
def normal_2d(n, mux, muy, sigmax, sigmay, corr):
    mean = [mux, muy]
    cov = [[sigmax**2, corr*sigmax*sigmay],[corr*sigmax*sigmay,sigmay**2]]
    d = np.random.multivariate_normal(mean, cov, n)
    return d[:,0], d[:,1]

# %%
def plot_normal_2d(n, mux, muy, sigmax, sigmay, corr):
    x, y = normal_2d(n, mux, muy, sigmax, sigmay, corr)
    plt.scatter(x, y, s=100, alpha=0.6)
    plt.axis([-10.0,10.0,-10.0,10.0])

# %%
interact(plot_normal_2d, n=(10,10000,10), mux=(-5.0,5.0,0.1), muy=(-5.0,5.0,0.1),
         sigmax=(0.01,5.0,0.00001), sigmay=(0.01,5.0,0.00001), corr=(-0.99,0.99,0.000001));

# %% [markdown]
# <br>
